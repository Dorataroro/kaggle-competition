# %%
import requests

url = 'https://api.bitflyer.com/v1/getboard'

product_name = "BTC_JPY"

params ={
         'product_code' : product_name,      # 取得するtweet数
         }

res = requests.get(url, params = params)

# %%
res = res.json()
# Out:
# {'mid_price': 926693.0,
#  'bids': [{'price': 926593.0, 'size': 1.967},
#   {'price': 926500.0, 'size': 0.041},
#   {'price': 926333.0, 'size': 0.267},
#   {'price': 926226.0, 'size': 0.0101},
#   {'price': 926069.0, 'size': 0.47249999},
#   {'price': 926061.0, 'size': 0.44999999},
#   {'price': 926000.0, 'size': 0.465},
#   {'price': 925890.0, 'size': 0.79},
#   {'price': 925861.0, 'size': 0.31},
#   {'price': 925740.0, 'size': 1.0},
#   {'price': 925514.0, 'size': 0.17452561},
#   {'price': 925500.0, 'size': 2.01},
#   {'price': 925493.0, 'size': 0.01},
#   {'price': 925151.0, 'size': 0.30000013},
#   {'price': 925150.0, 'size': 0.36},
#   {'price': 924804.0, 'size': 0.1},
#   {'price': 924732.0, 'size': 0.0052},
#   {'price': 924700.0, 'size': 0.06},
#   {'price': 924591.0, 'size': 1.4512},
#   {'price': 924500.0, 'size': 0.02},
#   {'price': 924480.0, 'size': 1.53},
#   {'price': 924393.0, 'size': 0.2},
#   {'price': 924310.0, 'size': 2.22},
# ...

# %%
res["mid_price"]
# Out:
# 926693.0
