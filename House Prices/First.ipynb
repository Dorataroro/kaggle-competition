# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",100)
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train_y=train["SalePrice"]
del train["SalePrice"]

# %%
total_data = pd.concat([train,test],ignore_index=True)

# %%
#データの加工
train_y = np.log(train_y+1)
total_data["GrLivArea"] = np.log(total_data["GrLivArea"]+1)
total_data["TotalBsmtSF"] = np.log(total_data["TotalBsmtSF"]+1)

# %%
#一旦一番シンプルなモデルを作る
#ラベルデータのエンコーディング
types=total_data.dtypes
object_columns = []
for k,v in types.items():
    if v == "object":
        object_columns.append(k)

for i in object_columns:
    le = LabelEncoder()
    total_data[i] = total_data[i].astype(str)
    le.fit(total_data[i])
    total_data[i] = le.transform(total_data[i])

# %%
#数値データの欠損値対応
nulls = total_data.isnull().sum()
null_columns = []
for k,v in nulls.items():
    if v != 0:
        null_columns.append(k)

#total_data[null_columns]
#total_data[null_columns].describe()
#total_data[["BsmtFinSF2","BsmtFullBath","BsmtHalfBath"]].fillna(0,inplace=True)
total_data.drop(null_columns,axis=1,inplace=True)

# %%
total_data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscFeature      0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
#データの再分割
del total_data["Id"]
test_x = total_data[len(train_y):]
x = total_data[:len(train_y)]
train_x,valid_x,train_y,valid_y = train_test_split(x,train_y,test_size=0.2)

# %%
test_x
# Out:
#       MSSubClass  MSZoning  LotArea  Street  Alley  LotShape  LandContour  \
# 1460          20         2    11622       1      2         3            3
# 1461          20         3    14267       1      2         0            3
# 1462          60         3    13830       1      2         0            3
# 1463          60         3     9978       1      2         0            3
# 1464         120         3     5005       1      2         0            1
# ...          ...       ...      ...     ...    ...       ...          ...
# 2914         160         4     1936       1      2         3            3
# 2915         160         4     1894       1      2         3            3
# 2916          20         3    20000       1      2         3            3
# 2917          85         3    10441       1      2         3            3
# 2918          60         3     9627       1      2         3            3
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 1460          0          4          0            12           1           2
# 1461          0          0          0            12           2           2
# 1462          0          4          0             8           2           2
# 1463          0          4          0             8           2           2
# 1464          0          4          0            22           2           2
# ...         ...        ...        ...           ...         ...         ...
# 2914          0          4          0            10           2           2
# 2915          0          4          0            10           2           2
# 2916          0          4          0            11           2           2
# 2917          0          4          0            11           2           2
# 2918          0          4          1            11           2           2
#
#       BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 1460         0           2            5            6       1961          1961
# 1461         0           2            6            6       1958          1958
# 1462         0           5            5            5       1997          1998
# 1463         0           5            6            6       1998          1998
# 1464         4           2            8            5       1992          1992
# ...        ...         ...          ...          ...        ...           ...
# 2914         3           5            4            7       1970          1970
# 2915         4           5            4            5       1970          1970
# 2916         0           2            5            7       1960          1996
# 2917         0           6            5            5       1992          1992
# 2918         0           5            7            5       1993          1994
#
#       RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  ExterQual  \
# 1460          1         1           12           13           2          3
# 1461          3         1           13           14           1          3
# 1462          1         1           12           13           2          3
# 1463          1         1           12           13           1          3
# 1464          1         1            6            6           2          2
# ...         ...       ...          ...          ...         ...        ...
# 2914          1         1            5            5           2          3
# 2915          1         1            5            5           2          3
# 2916          1         1           12           13           2          3
# 2917          1         1            6           15           2          3
# 2918          1         1            6            6           1          3
#
#       ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# 1460          4           1         3         3             3             4
# 1461          4           1         3         3             3             0
# 1462          4           2         2         3             3             2
# 1463          4           2         3         3             3             2
# 1464          4           2         2         3             3             0
# ...         ...         ...       ...       ...           ...           ...
# 2914          4           1         3         3             3             5
# 2915          4           1         3         3             3             4
# 2916          4           1         3         3             3             0
# 2917          4           2         2         3             0             2
# 2918          4           2         2         3             0             3
#
#       BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  1stFlrSF  \
# 1460             3        1          4           1           4       896
# 1461             5        1          4           1           4      1329
# 1462             5        1          2           1           4       928
# 1463             5        1          0           1           4       926
# 1464             5        1          0           1           4      1280
# ...            ...      ...        ...         ...         ...       ...
# 2914             5        1          2           1           4       546
# 2915             5        1          4           1           4       546
# 2916             5        1          0           1           4      1224
# 2917             5        1          4           1           4       970
# 2918             5        1          0           1           4       996
#
#       2ndFlrSF  LowQualFinSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 1460         0             0   6.799056         1         0             2
# 1461         0             0   7.192934         1         1             3
# 1462       701             0   7.396335         2         1             3
# 1463       678             0   7.380879         2         1             3
# 1464         0             0   7.155396         2         0             2
# ...        ...           ...        ...       ...       ...           ...
# 2914       546             0   6.996681         1         1             3
# 2915       546             0   6.996681         1         1             3
# 2916         0             0   7.110696         1         0             4
# 2917         0             0   6.878326         1         0             3
# 2918      1004             0   7.601402         2         1             3
#
#       KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  \
# 1460             1            3             5           6           0
# 1461             1            2             6           6           0
# 1462             1            3             6           6           1
# 1463             1            2             7           6           1
# 1464             1            2             5           6           0
# ...            ...          ...           ...         ...         ...
# 2914             1            3             5           6           0
# 2915             1            3             6           6           0
# 2916             1            3             7           6           1
# 2917             1            3             6           6           0
# 2918             1            3             9           6           1
#
#       FireplaceQu  GarageType  GarageFinish  GarageQual  GarageCond  \
# 1460            5           1             2           4           4
# 1461            5           1             2           4           4
# 1462            4           1             0           4           4
# 1463            2           1             0           4           4
# 1464            5           1             1           4           4
# ...           ...         ...           ...         ...         ...
# 2914            5           6             3           5           5
# 2915            5           4             2           4           4
# 2916            4           5             2           4           4
# 2917            5           6             3           5           5
# 2918            4           1             0           4           4
#
#       PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 1460           2         140            0              0          0
# 1461           2         393           36              0          0
# 1462           2         212           34              0          0
# 1463           2         360           36              0          0
# 1464           2           0           82              0          0
# ...          ...         ...          ...            ...        ...
# 2914           2           0            0              0          0
# 2915           2           0           24              0          0
# 2916           2         474            0              0          0
# 2917           2          80           32              0          0
# 2918           2         190           48              0          0
#
#       ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  MoSold  \
# 1460          120         0       3      2            4        0       6
# 1461            0         0       3      4            0    12500       6
# 1462            0         0       3      2            4        0       3
# 1463            0         0       3      4            4        0       6
# 1464          144         0       3      4            4        0       1
# ...           ...       ...     ...    ...          ...      ...     ...
# 2914            0         0       3      4            4        0       6
# 2915            0         0       3      4            4        0       4
# 2916            0         0       3      4            4        0       9
# 2917            0         0       3      2            2      700       7
# 2918            0         0       3      4            4        0      11
#
#       YrSold  SaleType  SaleCondition
# 1460    2010         8              4
# 1461    2010         8              4
# 1462    2010         8              4
# 1463    2010         8              4
# 1464    2010         8              4
# ...      ...       ...            ...
# 2914    2006         8              4
# 2915    2006         8              0
# 2916    2006         8              0
# 2917    2006         8              4
# 2918    2006         8              4
#
# [1459 rows x 68 columns]

# %%
#モデルの構築
model = XGBRegressor(
    max_depth = 5,
    n_estimators=1000,
    min_child_weight=1, #1.0がベースライン
    colsample_bytree=0.8,
    subsample=0.8,
    eta=0.3,
    seed=42
)
model.fit(
    train_x,
    train_y,
    eval_metric="rmse",
    eval_set=[(train_x,train_y),(valid_x,valid_y)],
    verbose=True,
    early_stopping_rounds = 10
)
# Out:
# [20:12:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10.3721	validation_1-rmse:10.4187
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse
# [56]	validation_0-rmse:0.093698	validation_1-rmse:0.142753
# [57]	validation_0-rmse:0.091865	validation_1-rmse:0.14107
# [58]	validation_0-rmse:0.090239	validation_1-rmse:0.139712
# [59]	validation_0-rmse:0.088648	validation_1-rmse:0.13827
# [60]	validation_0-rmse:0.087315	validation_1-rmse:0.1371
# [61]	validation_0-rmse:0.086129	validation_1-rmse:0.137026
# [62]	validation_0-rmse:0.084538	validation_1-rmse:0.136114
# [63]	validation_0-rmse:0.083369	validation_1-rmse:0.135487
# [64]	validation_0-rmse:0.082358	validation_1-rmse:0.134669
# [65]	validation_0-rmse:0.081124	validation_1-rmse:0.134135
# [66]	validation_0-rmse:0.080107	validation_1-rmse:0.133839
# [67]	validation_0-rmse:0.079033	validation_1-rmse:0.133344
# [68]	validation_0-rmse:0.07791	validation_1-rmse:0.133209
# [69]	validation_0-rmse:0.077066	validation_1-rmse:0.132988
# [70]	validation_0-rmse:0.076065	validation_1-rmse:0.133142
# [71]	validation_0-rmse:0.075002	validation_1-rmse:0.132579
# [72]	validation_0-rmse:0.07393	validation_1-rmse:0.13241
# [73]	validation_0-rmse:0.073033	validation_1-rmse:0.132354
# [74]	validation_0-rmse:0.072405	validation_1-rmse:0.131959
# [75]	validation_0-rmse:0.071467	validation_1-rmse:0.132099
# [76]	validation_0-rmse:0.070466	validation_1-rmse:0.131528
# [77]	validation_0-rmse:0.069913	validation_1-rmse:0.131549
# [78]	validation_0-rmse:0.069186	validation_1-rmse:0.131164
# [79]	validation_0-rmse:0.068348	validation_1-rmse:0.130889
# [80]	validation_0-rmse:0.067844	validation_1-rmse:0.130817
# [81]	validation_0-rmse:0.0673	validation_1-rmse:0.130871
# [82]	validation_0-rmse:0.066758	validation_1-rmse:0.130621
# [83]	validation_0-rmse:0.066303	validation_1-rmse:0.13025
# [84]	validation_0-rmse:0.065682	validation_1-rmse:0.13029
# [85]	validation_0-rmse:0.065439	validation_1-rmse:0.130248
# [86]	validation_0-rmse:0.064949	validation_1-rmse:0.129979
# [87]	validation_0-rmse:0.064357	validation_1-rmse:0.129994
# [88]	validation_0-rmse:0.064077	validation_1-rmse:0.12992
# [89]	validation_0-rmse:0.063336	validation_1-rmse:0.129673
# [90]	validation_0-rmse:0.062639	validation_1-rmse:0.129468
# [91]	validation_0-rmse:0.062207	validation_1-rmse:0.129475
# [92]	validation_0-rmse:0.061752	validation_1-rmse:0.129478
# [93]	validation_0-rmse:0.061066	validation_1-rmse:0.129364
# [94]	validation_0-rmse:0.060573	validation_1-rmse:0.129447
# [95]	validation_0-rmse:0.060311	validation_1-rmse:0.129394
# [96]	validation_0-rmse:0.059855	validation_1-rmse:0.12941
# [97]	validation_0-rmse:0.059435	validation_1-rmse:0.129255
# [98]	validation_0-rmse:0.058999	validation_1-rmse:0.129126
# [99]	validation_0-rmse:0.058637	validation_1-rmse:0.129197
# [100]	validation_0-rmse:0.058353	validation_1-rmse:0.129136
# [101]	validation_0-rmse:0.057902	validation_1-rmse:0.12918
# [102]	validation_0-rmse:0.057485	validation_1-rmse:0.129129
# [103]	validation_0-rmse:0.056898	validation_1-rmse:0.129114
# [104]	validation_0-rmse:0.056338	validation_1-rmse:0.128875
# [105]	validation_0-rmse:0.056113	validation_1-rmse:0.128851
# [106]	validation_0-rmse:0.055947	validation_1-rmse:0.128758
# [107]	validation_0-rmse:0.055507	validation_1-rmse:0.129019
# [108]	validation_0-rmse:0.054972	validation_1-rmse:0.128918
# [109]	validation_0-rmse:0.05444	validation_1-rmse:0.128857
# [110]	validation_0-rmse:0.054104	validation_1-rmse:0.128695
# [111]	validation_0-rmse:0.053705	validation_1-rmse:0.12874
# [112]	validation_0-rmse:0.053462	validation_1-rmse:0.128767
# [113]	validation_0-rmse:0.05311	validation_1-rmse:0.128726
# [114]	validation_0-rmse:0.052557	validation_1-rmse:0.128822
# [115]	validation_0-rmse:0.052235	validation_1-rmse:0.128832
# [116]	validation_0-rmse:0.051922	validation_1-rmse:0.128717
# [117]	validation_0-rmse:0.05159	validation_1-rmse:0.128532
# [118]	validation_0-rmse:0.0514	validation_1-rmse:0.128568
# [119]	validation_0-rmse:0.05099	validation_1-rmse:0.128414
# [120]	validation_0-rmse:0.050578	validation_1-rmse:0.128351
# [121]	validation_0-rmse:0.050094	validation_1-rmse:0.128495
# [122]	validation_0-rmse:0.049764	validation_1-rmse:0.128522
# [123]	validation_0-rmse:0.049347	validation_1-rmse:0.128579
# [124]	validation_0-rmse:0.049052	validation_1-rmse:0.128645
# [125]	validation_0-rmse:0.048617	validation_1-rmse:0.128516
# [126]	validation_0-rmse:0.048312	validation_1-rmse:0.128611
# [127]	validation_0-rmse:0.048064	validation_1-rmse:0.128657
# [128]	validation_0-rmse:0.047625	validation_1-rmse:0.128722
# [129]	validation_0-rmse:0.047323	validation_1-rmse:0.128584
# [130]	validation_0-rmse:0.047096	validation_1-rmse:0.128393
# Stopping. Best iteration:
# [120]	validation_0-rmse:0.050578	validation_1-rmse:0.128351
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=5, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.8, verbosity=1)

# %%
#結果の予測
y_train_pred = model.predict(train_x)
y_valid_pred = model.predict(valid_x)
y_test_pred = model.predict(test_x)

# %%
#結果の検証
print("学習データのRMSE: " + str(np.sqrt(mean_squared_error(train_y,y_train_pred))))
print("検証データのRMSE: " +  str(np.sqrt(mean_squared_error(valid_y,y_valid_pred))))
# Out:
# 学習データのRMSE: 0.05057812148030681
# 検証データのRMSE: 0.12835121328350385

# %%
result = pd.DataFrame({
    "Id":test["Id"],
    "SalePrice":(np.exp(y_test_pred)-1)
})

# %%
result.to_csv("result2.csv",index=False,header=True)

# %%
#追加で色々分析する
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
train["SalePrice"].describe()

# %%
sns.distplot(train["SalePrice"])

# %%
#Relationship with numerical variables
var = "GrLivArea"
data = pd.concat([train["SalePrice"],train[var]],axis=1)
data.plot.scatter(x=var,y="SalePrice",ylim=(0.8));
var = "TotalBsmtSF"
data = pd.concat([train["SalePrice"],train[var]],axis=1)
data.plot.scatter(x=var,y="SalePrice",ylim=(0.8));

# %%
#Relationship with categorical features
var = "OverallQual"
data = pd.concat([train["SalePrice"],train[var]],axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var,y="SalePrice",data=data)
fig.axis(ymin=0,ymax=800000);

# %%
var = 'YearBuilt'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);

# %%
#correlation matrix
corrmat = train.corr()
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
k = 10
cols = corrmat.nlargest(k,"SalePrice")["SalePrice"].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm,cbar=True,annot=True,square=True,fmt=".2f",annot_kws={"size":10},yticklabels=cols.values,xticklabels=cols.values)

# %%
#Normalize Data
test["SalePrice"] = np.log(train["SalePrice"]+1)
sns.distplot(test["SalePrice"])
fig = plt.figure()
